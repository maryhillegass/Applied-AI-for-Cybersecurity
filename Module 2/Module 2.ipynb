# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# python3 -m venv .venv #creating a virtual environment for the project
# .\.venv\Scripts\activate #activating the virtual environment
#
# pip install openai python-dotenv pandas jupyter #installing the required packages for the project
# pip freeze > requirements.txt #saving the installed packages in requirements.txt file for reproducibility
#
# # In VS Code : Crtl+Shift+P > Python: Select Interpreter > .venv\Scripts\python.exe
