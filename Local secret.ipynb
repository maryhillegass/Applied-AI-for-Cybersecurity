# %% [markdown]
# <a href="https://colab.research.google.com/github/maryhillegass/Applied-AI-for-Cybersecurity/blob/main/Secrets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

# %pip install -q -U google-genai

import google.genai as genai
from dotenv import load_dotenv

load_dotenv()

api_key = os.getenv("GEMINI_API_KEY")
if not api_key:
    raise RuntimeError(
        "GEMINI_API_KEY was not found. Add it to a .env file in the workspace root."
    )

client = genai.Client(api_key=api_key)

response = client.models.generate_content(
    model="gemini-3.6-flash",
    contents="Explain what an SNS topic is in one sentence.",
)

print(response.text)
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[2], line 18
#      14     )
#      15
#      16 client = genai.Client(api_key=api_key)
#      17
# ---> 18 response = client.models.generate_content(
#      19     model="gemini-2.5-flash",
#      20     contents="Explain what an SNS topic is in one sentence.",
#      21 )
#
# File ~\Documents\UC\IT7075C - Applied AI\Applied AI for Cybersecurity\.venv\Lib\site-packages\google\genai\models.py:6270, in Models.generate_content(self, model, contents, config)
#    6264   parsed_config_to_call = _extra_utils.get_usage_header(
#    6265       parsed_config_to_call,
#    6266       types.GenerateContentConfig,
#    6267       'afc',
#    6268   )
#    6269 i += 1
# -> 6270 response = self._generate_content(
# ...
